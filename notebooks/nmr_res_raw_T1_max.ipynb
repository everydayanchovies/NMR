# %%
# import pandas as pd
# import numpy as np
# import math
import matplotlib.pyplot as plt
import matplotlib as mpl
# from lmfit import models
from utils.scopeutil import *
from utils.OOMFormatter import OOMFormatter

mpl.rcParams['figure.dpi'] = 300

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_KOPERCHLORIDE_ACETOON,
        verhouding="1_1",
        T=T1,
        signal_index=SI_SIGNAL)[4:]:

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_z$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-3, "%1.1f"))
plt.ylim([0, 40])
plt.title("Ruwe T1 metingen koperchloride aceton 1:1")
plt.savefig("../plots/raw_T1_koperchloride_acetoon_1_1.png", dpi=800)
fig.show()
# Out:
# <ipython-input-76-4d3447639929>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_KOPERCHLORIDE_A,
        verhouding="1_0",
        T=T1,
        signal_index=SI_SIGNAL):

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_z$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
plt.ylim([0, 60])
plt.title("Ruwe T1 metingen koperchloride(A)")
plt.savefig("../plots/raw_T1_koperchlorideA.png", dpi=800)
fig.show()
# Out:
# <ipython-input-77-d0a80f9aa722>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_KOPERCHLORIDE_B,
        verhouding="1_0",
        T=T1,
        signal_index=SI_SIGNAL):

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_z$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
plt.ylim([0, 60])
plt.title("Ruwe T1 metingen koperchloride(B)")
plt.savefig("../plots/raw_T1_koperchlorideB.png", dpi=800)
fig.show()
# Out:
# <ipython-input-78-2ff09d175203>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_KOPERCHLORIDE_B,
        verhouding="1_1",
        T=T1,
        signal_index=SI_SIGNAL):

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_z$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
plt.ylim([0, 60])
plt.title("Ruwe T1 metingen koperchloride(B) water 1:1")
plt.savefig("../plots/raw_T1_koperchlorideB_water_1_1.png", dpi=800)
fig.show()
# Out:
# <ipython-input-79-c5b60b916f96>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_ACETOON,
        verhouding="1_0",
        T=T1,
        signal_index=SI_SIGNAL):

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_z$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
plt.ylim([0, 60])
plt.title("Ruwe T1 metingen aceton")
plt.savefig("../plots/raw_T1_aceton.png", dpi=800)
fig.show()
# Out:
# <ipython-input-80-45b130ca02fd>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
