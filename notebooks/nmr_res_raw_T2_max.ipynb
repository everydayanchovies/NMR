# %%
# import pandas as pd
# import numpy as np
# import math
import matplotlib.pyplot as plt
import matplotlib as mpl
# from lmfit import models
from utils.scopeutil import *
from utils.OOMFormatter import OOMFormatter

mpl.rcParams['figure.dpi'] = 300

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_KOPERCHLORIDE_ACETOON,
        verhouding="1_1",
        T=T2,
        signal_index=SI_SIGNAL):

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_y$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
plt.ylim([0, 50])
plt.title("Ruwe T2 metingen koperchloride aceton 1:1")
plt.savefig("../plots/raw_T2_koperchloride_acetoon_1_1.png", dpi=800)
fig.show()
# Out:
# <ipython-input-17-c6c7a7afc18f>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()

for (delay, df) in get_df_of_all_delays(
        stof=STOF_ACETOON,
        verhouding="1_0",
        T=T2,
        signal_index=SI_SIGNAL):

    ax.plot(df['x'], df['y'], alpha=1)

plt.xlabel(r"Delay [sec]")
plt.ylabel(r"Gemeten spanning, evenredig met $M_y$ [$V$]")
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.1f"))
plt.ylim([0, 30])
plt.title("Ruwe T2 aceton")
plt.savefig("../plots/raw_T2_aceton.png", dpi=800)
fig.show()
# Out:
# <ipython-input-18-311122692ddb>:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
