# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib
from lmfit import models
import utils.scopeutil as scope

# %%
SI_PULSE_SIGNAL = 1
SI_READ_SIGNAL = 2

for delay in range(400, 800, 50):
    for signal_index in [SI_PULSE_SIGNAL, SI_READ_SIGNAL]:
        df = scope.xy_for_scope_csv(scope.path_for_measurement_params(delay, signal_index))
        plt.plot(df['x'], df['y'])
    plt.show()
