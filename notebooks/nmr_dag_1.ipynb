# %%
# import pandas as pd
# import numpy as np
# import math
import matplotlib.pyplot as plt
# import matplotlib
# from lmfit import models
from utils.scopeutil import *
from utils.OOMFormatter import OOMFormatter

# %%
get_df(STOF_KOPERCHLORIDE, "1_4", T1, 500, SI_SIGNAL).plot()

# %%
for df in get_df_of_all_delays(STOF_KOPERCHLORIDE, "1_4", T1, SI_SIGNAL):
    df.plot()

# %%
mogelijke_verhoudingen_van_koperchloride = get_verhoudingen(STOF_KOPERCHLORIDE)

for verhouding in mogelijke_verhoudingen_van_koperchloride:
    mogelijke_delays_van_koperchloride = get_delays(STOF_KOPERCHLORIDE, verhouding, T1)
    eerste_delay = mogelijke_delays_van_koperchloride[0]
    
    get_df(STOF_KOPERCHLORIDE, verhouding, T1, eerste_delay, SI_SIGNAL).plot()
